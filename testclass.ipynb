# %%
from polymer_chain import Polymer
import os

# %%
x = os.path.join(os.getcwd(), "test")
print(type(x))
print(type("test"))
print(type(os.getcwd()))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
p = Polymer(n_beeds=30, mobility=0.000005, q_beed=0, epsilon_LJ=0)
p.create_chain(axis=0)
p.simulate(steps=10000)
p.plot_distance_distribution(n_bins=500)
# Out:
# (1.7973947760469695, 2.3277381284225815)

# %%
p.plot_distance_distribution(n_bins=500)
# Out:
# (1.7436308629222632, 2.3138467205904445)
